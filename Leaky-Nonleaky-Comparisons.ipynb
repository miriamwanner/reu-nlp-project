# %%
import REUParsing as rp
import os
from tqdm import tqdm

# %%
leaky_trees = rp.load_sentences("D:/REU Datasets/Universal Dependencies 2.8.1/leaky-treebanks/Unlabeled/UD_Faroese-FarPaHC/fo_farpahc-ud-train.conllu")
nonleaky_trees = rp.load_sentences("D:/REU Datasets/Universal Dependencies 2.8.1/nonleaky-treebanks/Unlabeled/UD_Faroese-FarPaHC/fo_farpahc-ud-train.conllu")

# %%
leaky_trees[0]
# Out:
# TokenTree<token={id=4, form=fyrstuni}, children=[...]>

# %%
# The depth of a tree from a node
def depth(node):
    if len(node.children) > 0:
        max_child_depth = 0
        for child in node.children:
            child_depth = depth(child)
            if child_depth > max_child_depth:
                max_child_depth = child_depth
        return max_child_depth + 1
    else:
        return 0

# %%
def avg_depth(trees):
    return sum([depth(tree) for tree in trees])/len(trees)

# %%
depth(nonleaky_trees[1])
# Out:
# 4

# %%
print(avg_depth(leaky_trees))
print(avg_depth(nonleaky_trees))
# Out:
# 2.5609756097560976
# 4.687436159346272

# %%
# The number of nodes in a tree
def tree_size(tree):
    size = 1
    for child in tree.children:
        size += tree_size(child)
    return size

# %%
def avg_tree_size(trees):
    return sum([tree_size(tree) for tree in trees])/len(trees)

# %%
tree_size(nonleaky_trees[1])
# Out:
# 22

# %%
print(avg_tree_size(leaky_trees))
print(avg_tree_size(nonleaky_trees))
# Out:
# 8.048780487804878
# 23.252298263534218

# %%
def total_relation_length(node, parent = None):
    if parent is None:
        return sum([total_relation_length(child, node) for child in node.children])
    if len(node.children) > 0:
        return sum([total_relation_length(child, node) for child in node.children]) + abs(node.token["id"] - parent.token["id"])
    else:
        return abs(node.token["id"] - parent.token["id"])

# %%
total_relation_length(nonleaky_trees[1])/tree_size(nonleaky_trees[1])
# Out:
# 2.0

# %%
def avg_relation_length(trees):
    total_size = 0
    total_length = 0
    for tree in trees:
        total_size += tree_size(tree)
        total_length += total_relation_length(tree)
    return total_length / total_size

# %%
avg_relation_length(leaky_trees)
# Out:
# 1.4636363636363636

# %%
treetype = ["train", "train", "test", "test"]
leakage = ["leaky", "nonleaky", "leaky", "nonleaky"]
features = {
    "leaky": {
        "train":{},
        "test":{}
    },
    "nonleaky":{
        "train":{},
        "test":{}
    }
}

for x in range(4):
    for treebank in tqdm(os.listdir(f"D:/REU Datasets/Universal Dependencies 2.8.1/{leakage[x]}-treebanks/Unlabeled/")):
        for file in os.listdir(f"D:/REU Datasets/Universal Dependencies 2.8.1/{leakage[x]}-treebanks/Unlabeled/{treebank}/"):
            if file.endswith(f"-ud-{treetype[x]}.conllu"):
                features[leakage[x]][treetype[x]][treebank] = {}
                trees = rp.load_sentences(f"D:/REU Datasets/Universal Dependencies 2.8.1/{leakage[x]}-treebanks/Unlabeled/{treebank}/{file}")
                features[leakage[x]][treetype[x]][treebank]["num_trees"] = len(trees)
                
                if len(trees) > 0:
                    features[leakage[x]][treetype[x]][treebank]["avg_depth"] = avg_depth(trees)
                    features[leakage[x]][treetype[x]][treebank]["avg_size"] = avg_tree_size(trees)
                    features[leakage[x]][treetype[x]][treebank]["avg_rel_length"] = avg_relation_length(trees)
                else:
                    features[leakage[x]][treetype[x]][treebank]["avg_depth"] = 0
                    features[leakage[x]][treetype[x]][treebank]["avg_size"] = 0
                    features[leakage[x]][treetype[x]][treebank]["avg_rel_length"] = 0
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 202/202 [01:50<00:00,  1.82it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 202/202 [08:52<00:00,  2.64s/it]
# 100%|████████████████████████████████████████████████████████████████████████████████| 202/202 [00:20<00:00,  9.68it/s]
# 100%|████████████████████████████████████████████████████████████████████████████████| 202/202 [01:26<00:00,  2.33it/s]

# %%
for leakage in features:
    for treetype in features[leakage]:
        total_depth = 0
        total_size = 0
        total_rel_length = 0
        total_num_trees = 0
        for treebank in features[leakage][treetype]:
            total_depth += features[leakage][treetype][treebank]["avg_depth"] * features[leakage][treetype][treebank]["num_trees"]
            total_size += features[leakage][treetype][treebank]["avg_size"] * features[leakage][treetype][treebank]["num_trees"]
            total_rel_length += features[leakage][treetype][treebank]["avg_rel_length"] * features[leakage][treetype][treebank]["avg_size"] * features[leakage][treetype][treebank]["num_trees"]
            total_num_trees += features[leakage][treetype][treebank]["num_trees"]
        total_avg_depth = total_depth / total_num_trees
        total_avg_size = total_size / total_num_trees
        total_avg_rel_length = total_rel_length / total_size
        print(f"Average {leakage} {treetype} tree depth:", total_avg_depth)
        print(f"Average {leakage} {treetype} tree size:", total_avg_size)
        print(f"Average {leakage} {treetype} dependency length:", total_avg_rel_length)
# Out:
# Average leaky train tree depth: 2.2010348035529956
# Average leaky train tree size: 7.214471107486183
# Average leaky train dependency length: 1.9831152474450007
# Average leaky test tree depth: 2.4286077850026087
# Average leaky test tree size: 8.416252051866085
# Average leaky test dependency length: 2.187663288015869
# Average nonleaky train tree depth: 4.837531232831223
# Average nonleaky train tree size: 24.12125560368625
# Average nonleaky train dependency length: 3.419120111454377
# Average nonleaky test tree depth: 4.3977084208896455
# Average nonleaky test tree size: 21.580304806565064
# Average nonleaky test dependency length: 3.3320623518896624

# %%
features
# Out:
# {'leaky': {'train': {'UD_Afrikaans-AfriBooms': {'num_trees': 59,
#     'avg_depth': 2.5762711864406778,
#     'avg_size': 10.033898305084746,
#     'avg_rel_length': 2.2905405405405403},
#    'UD_Ancient_Greek-Perseus': {'num_trees': 5112,
#     'avg_depth': 2.1709702660406887,
#     'avg_size': 7.752347417840376,
#     'avg_rel_length': 2.170275044158466},
#    'UD_Ancient_Greek-PROIEL': {'num_trees': 7732,
#     'avg_depth': 2.0786342472840147,
#     'avg_size': 6.193093636833937,
#     'avg_rel_length': 1.7968674950402004},
#    'UD_Arabic-NYUAD': {'num_trees': 1070,
#     'avg_depth': 1.8822429906542055,
#     'avg_size': 5.9392523364485985,
#     'avg_rel_length': 1.7601888276947286},
#    'UD_Arabic-PADT': {'num_trees': 471,
#     'avg_depth': 2.307855626326964,
#     'avg_size': 5.008492569002123,
#     'avg_rel_length': 1.3098770665536243},
#    'UD_Armenian-ArmTDP': {'num_trees': 331,
#     'avg_depth': 1.8882175226586102,
#     'avg_size': 6.169184290030212,
#     'avg_rel_length': 1.7277179236043094},
#    'UD_Basque-BDT': {'num_trees': 2351,
#     'avg_depth': 2.4100382815823056,
#     'avg_size': 8.380263717566994,
#     'avg_rel_length': 2.0218251954116333},
#    'UD_Belarusian-HSE': {'num_trees': 11486,
#     'avg_depth': 2.030471878808985,
#     'avg_size': 6.012972314121539,
#     'avg_rel_length': 1.7072178382682979},
#    'UD_Bulgarian-BTB': {'num_trees': 3705,
#     'avg_depth': 2.251012145748988,
#     'avg_size': 7.221592442645075,
#     'avg_rel_length': 1.963895948572283},
#    'UD_Buryat-BDT': {'num_trees': 14,
#     'avg_depth': 2.2142857142857144,
#     'avg_size': 6.357142857142857,
#     'avg_rel_length': 1.4269662921348314},
#    'UD_Catalan-AnCora': {'num_trees': 837,
#     'avg_depth': 2.206690561529271,
#     'avg_size': 8.194743130227002,
#     'avg_rel_length': 2.040384895757399},
#    'UD_Chinese-GSD': {'num_trees': 126,
#     'avg_depth': 3.1587301587301586,
#     'avg_size': 12.206349206349206,
#     'avg_rel_length': 2.4258777633289985},
#    'UD_Chinese-GSDSimp': {'num_trees': 122,
#     'avg_depth': 3.1557377049180326,
#     'avg_size': 12.401639344262295,
#     'avg_rel_length': 2.452081956378057},
#    'UD_Classical_Chinese-Kyoto': {'num_trees': 43973,
#     'avg_depth': 1.8734450685648012,
#     'avg_size': 4.549905623905579,
#     'avg_rel_length': 1.2765590559445803},
#    'UD_Coptic-Scriptorium': {'num_trees': 68,
#     'avg_depth': 2.5588235294117645,
#     'avg_size': 10.294117647058824,
#     'avg_rel_length': 2.3214285714285716},
#    'UD_Croatian-SET': {'num_trees': 913,
#     'avg_depth': 2.419496166484118,
#     'avg_size': 8.49288061336254,
#     'avg_rel_length': 2.0598400825380447},
#    'UD_Czech-CAC': {'num_trees': 4300,
#     'avg_depth': 2.2181395348837207,
#     'avg_size': 7.129302325581396,
#     'avg_rel_length': 1.9103601252609603},
#    'UD_Czech-CLTT': {'num_trees': 163,
#     'avg_depth': 0.4662576687116564,
#     'avg_size': 1.6012269938650308,
#     'avg_rel_length': 0.5632183908045977},
#    'UD_Czech-FicTree': {'num_trees': 5158,
#     'avg_depth': 1.9112058937572702,
#     'avg_size': 6.957735556417216,
#     'avg_rel_length': 2.0887204636647345},
#    'UD_Czech-PDT': {'num_trees': 27402,
#     'avg_depth': 2.359207357127217,
#     'avg_size': 7.554850010948106,
#     'avg_rel_length': 2.102744688867635},
#    'UD_Danish-DDT': {'num_trees': 1050,
#     'avg_depth': 1.7933333333333332,
#     'avg_size': 6.2438095238095235,
#     'avg_rel_length': 1.9360890787065284},
#    'UD_Dutch-Alpino': {'num_trees': 4319,
#     'avg_depth': 2.081963417457745,
#     'avg_size': 7.168789071544339,
#     'avg_rel_length': 2.0191848071829983},
#    'UD_Dutch-LassySmall': {'num_trees': 2814,
#     'avg_depth': 1.648542999289268,
#     'avg_size': 4.967661691542289,
#     'avg_rel_length': 1.6642106016167109},
#    'UD_English-ESL': {'num_trees': 611,
#     'avg_depth': 2.3715220949263505,
#     'avg_size': 8.937806873977086,
#     'avg_rel_length': 2.148690715986083},
#    'UD_English-EWT': {'num_trees': 5104,
#     'avg_depth': 1.7921238244514106,
#     'avg_size': 6.033503134796239,
#     'avg_rel_length': 1.9494398441305407},
#    'UD_English-GUM': {'num_trees': 1800,
#     'avg_depth': 1.78,
#     'avg_size': 5.908333333333333,
#     'avg_rel_length': 1.8234132581100142},
#    'UD_English-GUMReddit': {'num_trees': 108,
#     'avg_depth': 1.3518518518518519,
#     'avg_size': 5.064814814814815,
#     'avg_rel_length': 1.7074954296160878},
#    'UD_English-LinES': {'num_trees': 983,
#     'avg_depth': 2.150559511698881,
#     'avg_size': 7.841302136317395,
#     'avg_rel_length': 2.0137519460300988},
#    'UD_English-ParTUT': {'num_trees': 42,
#     'avg_depth': 2.0714285714285716,
#     'avg_size': 7.285714285714286,
#     'avg_rel_length': 1.8431372549019607},
#    'UD_Estonian-EDT': {'num_trees': 11546,
#     'avg_depth': 2.121600554304521,
#     'avg_size': 7.535163693053872,
#     'avg_rel_length': 2.1208032091585154},
#    'UD_Estonian-EWT': {'num_trees': 1973,
#     'avg_depth': 1.6340598073998986,
#     'avg_size': 5.868220983274202,
#     'avg_rel_length': 1.9283986871653136},
#    'UD_Faroese-FarPaHC': {'num_trees': 41,
#     'avg_depth': 2.5609756097560976,
#     'avg_size': 8.048780487804878,
#     'avg_rel_length': 1.4636363636363636},
#    'UD_Finnish-FTB': {'num_trees': 10984,
#     'avg_depth': 2.1798980335032776,
#     'avg_size': 6.214949016751639,
#     'avg_rel_length': 1.420728045118289},
#    'UD_Finnish-TDT': {'num_trees': 5559,
#     'avg_depth': 2.1613599568267676,
#     'avg_size': 7.211368951250225,
#     'avg_rel_length': 1.9770005986828976},
#    'UD_French-FTB': {'num_trees': 1671,
#     'avg_depth': 2.0837821663674445,
#     'avg_size': 7.73608617594255,
#     'avg_rel_length': 2.033495784017947},
#    'UD_French-GSD': {'num_trees': 1040,
#     'avg_depth': 2.2884615384615383,
#     'avg_size': 8.310576923076923,
#     'avg_rel_length': 1.9337035751475182},
#    'UD_French-ParTUT': {'num_trees': 6,
#     'avg_depth': 2.3333333333333335,
#     'avg_size': 8.666666666666666,
#     'avg_rel_length': 1.8653846153846154},
#    'UD_French-Sequoia': {'num_trees': 470,
#     'avg_depth': 1.5957446808510638,
#     'avg_size': 4.580851063829787,
#     'avg_rel_length': 1.6637250348351138},
#    'UD_French-Spoken': {'num_trees': 590,
#     'avg_depth': 1.9322033898305084,
#     'avg_size': 5.908474576271186,
#     'avg_rel_length': 1.6201950659781985},
#    'UD_Galician-CTG': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Galician-TreeGal': {'num_trees': 86,
#     'avg_depth': 1.9069767441860466,
#     'avg_size': 5.872093023255814,
#     'avg_rel_length': 1.6752475247524752},
#    'UD_German-GSD': {'num_trees': 2962,
#     'avg_depth': 2.3426738690074274,
#     'avg_size': 8.970627954085078,
#     'avg_rel_length': 2.268300026344511},
#    'UD_German-HDT': {'num_trees': 65737,
#     'avg_depth': 2.5666671737377733,
#     'avg_size': 9.939592619072972,
#     'avg_rel_length': 2.6076562712829374},
#    'UD_Gothic-PROIEL': {'num_trees': 2128,
#     'avg_depth': 2.0615601503759398,
#     'avg_size': 5.87922932330827,
#     'avg_rel_length': 1.620973543281912},
#    'UD_Greek-GDT': {'num_trees': 159,
#     'avg_depth': 1.79874213836478,
#     'avg_size': 6.364779874213837,
#     'avg_rel_length': 1.8942687747035574},
#    'UD_Hebrew-HTB': {'num_trees': 334,
#     'avg_depth': 2.248502994011976,
#     'avg_size': 7.1017964071856285,
#     'avg_rel_length': 1.8478077571669478},
#    'UD_Hindi-HDTB': {'num_trees': 1926,
#     'avg_depth': 2.544132917964694,
#     'avg_size': 10.758047767393562,
#     'avg_rel_length': 2.2220559845559844},
#    'UD_Hindi_English-HIENCS': {'num_trees': 128,
#     'avg_depth': 2.75,
#     'avg_size': 10.71875,
#     'avg_rel_length': 2.253644314868805},
#    'UD_Hungarian-Szeged': {'num_trees': 69,
#     'avg_depth': 2.0579710144927534,
#     'avg_size': 7.391304347826087,
#     'avg_rel_length': 1.9},
#    'UD_Icelandic-IcePaHC': {'num_trees': 11408,
#     'avg_depth': 2.602208976157083,
#     'avg_size': 8.65524193548387,
#     'avg_rel_length': 1.6789718348372984},
#    'UD_Icelandic-Modern': {'num_trees': 1174,
#     'avg_depth': 3.24190800681431,
#     'avg_size': 13.09199318568995,
#     'avg_rel_length': 2.197202342225114},
#    'UD_Indonesian-CSUI': {'num_trees': 9,
#     'avg_depth': 2.888888888888889,
#     'avg_size': 8.88888888888889,
#     'avg_rel_length': 2.2375},
#    'UD_Indonesian-GSD': {'num_trees': 480,
#     'avg_depth': 2.7375,
#     'avg_size': 8.675,
#     'avg_rel_length': 1.9197886647454372},
#    'UD_Irish-IDT': {'num_trees': 455,
#     'avg_depth': 2.1032967032967034,
#     'avg_size': 6.674725274725275,
#     'avg_rel_length': 2.0424761277576557},
#    'UD_Italian-ISDT': {'num_trees': 2567,
#     'avg_depth': 2.384105960264901,
#     'avg_size': 7.971951694585119,
#     'avg_rel_length': 1.912724784988272},
#    'UD_Italian-ParTUT': {'num_trees': 30,
#     'avg_depth': 2.2333333333333334,
#     'avg_size': 7.666666666666667,
#     'avg_rel_length': 2.1130434782608694},
#    'UD_Italian-PoSTWITA': {'num_trees': 781,
#     'avg_depth': 1.9769526248399487,
#     'avg_size': 8.282970550576184,
#     'avg_rel_length': 2.289534703972793},
#    'UD_Italian-TWITTIRO': {'num_trees': 9,
#     'avg_depth': 2.2222222222222223,
#     'avg_size': 11.0,
#     'avg_rel_length': 2.474747474747475},
#    'UD_Italian-VIT': {'num_trees': 1476,
#     'avg_depth': 2.0372628726287263,
#     'avg_size': 7.257452574525745,
#     'avg_rel_length': 1.948562359970127},
#    'UD_Japanese-BCCWJ': {'num_trees': 15830,
#     'avg_depth': 2.095830701200253,
#     'avg_size': 7.7547062539482,
#     'avg_rel_length': 1.9289572081429165},
#    'UD_Japanese-GSD': {'num_trees': 855,
#     'avg_depth': 2.0982456140350876,
#     'avg_size': 7.439766081871345,
#     'avg_rel_length': 1.6637321175915736},
#    'UD_Kazakh-KTB': {'num_trees': 8,
#     'avg_depth': 2.5,
#     'avg_size': 7.375,
#     'avg_rel_length': 1.6610169491525424},
#    'UD_Korean-GSD': {'num_trees': 2038,
#     'avg_depth': 2.4342492639842983,
#     'avg_size': 6.098626104023553,
#     'avg_rel_length': 1.5264301230992035},
#    'UD_Korean-Kaist': {'num_trees': 9185,
#     'avg_depth': 2.8743603701687532,
#     'avg_size': 8.158192705498095,
#     'avg_rel_length': 1.6834772396674362},
#    'UD_Kurmanji-MG': {'num_trees': 10,
#     'avg_depth': 2.5,
#     'avg_size': 8.6,
#     'avg_rel_length': 1.872093023255814},
#    'UD_Latin-ITTB': {'num_trees': 7906,
#     'avg_depth': 2.173412598026815,
#     'avg_size': 7.583860359220845,
#     'avg_rel_length': 2.1525234330698155},
#    'UD_Latin-LLCT': {'num_trees': 2950,
#     'avg_depth': 3.943050847457627,
#     'avg_size': 10.00135593220339,
#     'avg_rel_length': 2.292367136659436},
#    'UD_Latin-Perseus': {'num_trees': 551,
#     'avg_depth': 2.2413793103448274,
#     'avg_size': 7.310344827586207,
#     'avg_rel_length': 2.0335153922542206},
#    'UD_Latin-PROIEL': {'num_trees': 9436,
#     'avg_depth': 2.022255192878338,
#     'avg_size': 5.791119118270454,
#     'avg_rel_length': 1.6674535639125263},
#    'UD_Latin-UDante': {'num_trees': 28,
#     'avg_depth': 2.0714285714285716,
#     'avg_size': 6.892857142857143,
#     'avg_rel_length': 1.9637305699481866},
#    'UD_Latvian-LVTB': {'num_trees': 3735,
#     'avg_depth': 2.1978580990629184,
#     'avg_size': 7.397054886211513,
#     'avg_rel_length': 2.0041262487331695},
#    'UD_Lithuanian-ALKSNIS': {'num_trees': 517,
#     'avg_depth': 2.1682785299806575,
#     'avg_size': 6.179883945841393,
#     'avg_rel_length': 1.770266040688576},
#    'UD_Lithuanian-HSE': {'num_trees': 4,
#     'avg_depth': 2.25,
#     'avg_size': 7.25,
#     'avg_rel_length': 1.6896551724137931},
#    'UD_Livvi-KKPP': {'num_trees': 4,
#     'avg_depth': 2.0,
#     'avg_size': 7.0,
#     'avg_rel_length': 1.5714285714285714},
#    'UD_Maltese-MUDT': {'num_trees': 246,
#     'avg_depth': 1.6788617886178863,
#     'avg_size': 5.365853658536586,
#     'avg_rel_length': 1.7068181818181818},
#    'UD_Marathi-UFAL': {'num_trees': 167,
#     'avg_depth': 1.7544910179640718,
#     'avg_size': 5.347305389221557,
#     'avg_rel_length': 1.3706606942889137},
#    'UD_Naija-NSC': {'num_trees': 3498,
#     'avg_depth': 1.7978845054316752,
#     'avg_size': 7.175528873642081,
#     'avg_rel_length': 2.010398406374502},
#    'UD_North_Sami-Giella': {'num_trees': 1897,
#     'avg_depth': 1.7332630469161834,
#     'avg_size': 6.241433842909857,
#     'avg_rel_length': 1.745777027027027},
#    'UD_Norwegian-Bokmaal': {'num_trees': 6443,
#     'avg_depth': 2.0895545553313672,
#     'avg_size': 7.3282632314139375,
#     'avg_rel_length': 2.0434810233819043},
#    'UD_Norwegian-Nynorsk': {'num_trees': 4431,
#     'avg_depth': 2.0151207402392237,
#     'avg_size': 6.787632588580456,
#     'avg_rel_length': 1.9769251230216784},
#    'UD_Norwegian-NynorskLIA': {'num_trees': 2003,
#     'avg_depth': 1.5002496255616575,
#     'avg_size': 5.019470793809286,
#     'avg_rel_length': 1.7679530535110404},
#    'UD_Old_Church_Slavonic-PROIEL': {'num_trees': 2753,
#     'avg_depth': 1.8986560116236832,
#     'avg_size': 5.693425354159099,
#     'avg_rel_length': 1.5879800944238867},
#    'UD_Old_East_Slavic-RNC': {'num_trees': 39,
#     'avg_depth': 2.2564102564102564,
#     'avg_size': 6.846153846153846,
#     'avg_rel_length': 1.9176029962546817},
#    'UD_Old_East_Slavic-TOROT': {'num_trees': 9721,
#     'avg_depth': 2.026437609299455,
#     'avg_size': 6.05966464355519,
#     'avg_rel_length': 1.6027739109768104},
#    'UD_Old_French-SRCMF': {'num_trees': 9460,
#     'avg_depth': 2.0734672304439745,
#     'avg_size': 6.211522198731501,
#     'avg_rel_length': 1.708156770647198},
#    'UD_Persian-PerDT': {'num_trees': 8389,
#     'avg_depth': 2.5079270473238764,
#     'avg_size': 8.833591608058171,
#     'avg_rel_length': 2.087672896565684},
#    'UD_Persian-Seraji': {'num_trees': 554,
#     'avg_depth': 2.083032490974729,
#     'avg_size': 7.214801444043322,
#     'avg_rel_length': 1.9334500875656742},
#    'UD_Polish-LFG': {'num_trees': 11590,
#     'avg_depth': 1.9644521138912856,
#     'avg_size': 6.591630716134599,
#     'avg_rel_length': 1.8547586947131431},
#    'UD_Polish-PDB': {'num_trees': 6731,
#     'avg_depth': 2.481354924974001,
#     'avg_size': 8.204278710444214,
#     'avg_rel_length': 2.0522065081578327},
#    'UD_Portuguese-Bosque': {'num_trees': 1279,
#     'avg_depth': 1.9218139171227522,
#     'avg_size': 5.80140734949179,
#     'avg_rel_length': 1.697978436657682},
#    'UD_Portuguese-GSD': {'num_trees': 951,
#     'avg_depth': 2.430073606729758,
#     'avg_size': 8.813880126182966,
#     'avg_rel_length': 2.064423765211167},
#    'UD_Romanian-Nonstandard': {'num_trees': 3795,
#     'avg_depth': 2.281422924901186,
#     'avg_size': 8.367852437417655,
#     'avg_rel_length': 2.175872276105303},
#    'UD_Romanian-RRT': {'num_trees': 412,
#     'avg_depth': 2.3810679611650487,
#     'avg_size': 8.449029126213592,
#     'avg_rel_length': 2.045389255960931},
#    'UD_Romanian-SiMoNERo': {'num_trees': 10,
#     'avg_depth': 2.7,
#     'avg_size': 10.7,
#     'avg_rel_length': 1.9626168224299065},
#    'UD_Russian-GSD': {'num_trees': 669,
#     'avg_depth': 2.532137518684604,
#     'avg_size': 7.668161434977579,
#     'avg_rel_length': 1.8222222222222222},
#    'UD_Russian-SynTagRus': {'num_trees': 17516,
#     'avg_depth': 2.4449075131308518,
#     'avg_size': 8.225622288193652,
#     'avg_rel_length': 2.067906718489728},
#    'UD_Russian-Taiga': {'num_trees': 9075,
#     'avg_depth': 1.9209917355371902,
#     'avg_size': 5.7879889807162535,
#     'avg_rel_length': 1.7365875947149982},
#    'UD_Sanskrit-Vedic': {'num_trees': 2021,
#     'avg_depth': 1.946066303809995,
#     'avg_size': 5.158337456704602,
#     'avg_rel_length': 1.6182254196642687},
#    'UD_Scottish_Gaelic-ARCOSG': {'num_trees': 852,
#     'avg_depth': 1.9061032863849765,
#     'avg_size': 5.312206572769953,
#     'avg_rel_length': 1.614449845338047},
#    'UD_Serbian-SET': {'num_trees': 235,
#     'avg_depth': 2.246808510638298,
#     'avg_size': 8.068085106382979,
#     'avg_rel_length': 1.915084388185654},
#    'UD_Slovak-SNK': {'num_trees': 5219,
#     'avg_depth': 1.923165357348151,
#     'avg_size': 6.319601456217666,
#     'avg_rel_length': 1.8298769025529076},
#    'UD_Slovenian-SSJ': {'num_trees': 1636,
#     'avg_depth': 2.0599022004889975,
#     'avg_size': 7.595965770171149,
#     'avg_rel_length': 2.049810895630482},
#    'UD_Slovenian-SST': {'num_trees': 1382,
#     'avg_depth': 1.1114327062228655,
#     'avg_size': 4.068017366136035,
#     'avg_rel_length': 1.5828886517253646},
#    'UD_Spanish-AnCora': {'num_trees': 1323,
#     'avg_depth': 2.074829931972789,
#     'avg_size': 7.505668934240362,
#     'avg_rel_length': 1.9887210473313193},
#    'UD_Spanish-GSD': {'num_trees': 848,
#     'avg_depth': 2.5908018867924527,
#     'avg_size': 9.527122641509434,
#     'avg_rel_length': 2.075999504889219},
#    'UD_Swedish-LinES': {'num_trees': 1026,
#     'avg_depth': 2.11598440545809,
#     'avg_size': 7.780701754385965,
#     'avg_rel_length': 2.069522735813604},
#    'UD_Swedish-Talbanken': {'num_trees': 1502,
#     'avg_depth': 2.1025299600532623,
#     'avg_size': 7.206391478029294,
#     'avg_rel_length': 1.993440502586844},
#    'UD_Swedish_Sign_Language-SSLC': {'num_trees': 40,
#     'avg_depth': 1.225,
#     'avg_size': 3.775,
#     'avg_rel_length': 1.4635761589403973},
#    'UD_Tamil-TTB': {'num_trees': 38,
#     'avg_depth': 2.4473684210526314,
#     'avg_size': 8.263157894736842,
#     'avg_rel_length': 1.7738853503184713},
#    'UD_Telugu-MTG': {'num_trees': 978,
#     'avg_depth': 1.5081799591002045,
#     'avg_size': 4.583844580777096,
#     'avg_rel_length': 1.1354004015168413},
#    'UD_Turkish-BOUN': {'num_trees': 3681,
#     'avg_depth': 2.1426242868785654,
#     'avg_size': 6.253735397989677,
#     'avg_rel_length': 1.555516941789748},
#    'UD_Turkish-FrameNet': {'num_trees': 1774,
#     'avg_depth': 2.0986471251409244,
#     'avg_size': 6.1527621195039455,
#     'avg_rel_length': 1.3570316078790654},
#    'UD_Turkish-IMST': {'num_trees': 2241,
#     'avg_depth': 2.027666220437305,
#     'avg_size': 5.795180722891566,
#     'avg_rel_length': 1.4385154385154386},
#    'UD_Turkish-Kenet': {'num_trees': 10184,
#     'avg_depth': 2.3957187745483113,
#     'avg_size': 7.116653574234093,
#     'avg_rel_length': 1.5898090402340086},
#    'UD_Turkish-Penn': {'num_trees': 4741,
#     'avg_depth': 2.3929550727694577,
#     'avg_size': 7.060113900021093,
#     'avg_rel_length': 1.7089507648183557},
#    'UD_Turkish-Tourism': {'num_trees': 14711,
#     'avg_depth': 1.636462511046156,
#     'avg_size': 4.272585140371151,
#     'avg_rel_length': 1.0077640245648647},
#    'UD_Turkish_German-SAGT': {'num_trees': 161,
#     'avg_depth': 2.080745341614907,
#     'avg_size': 8.341614906832298,
#     'avg_rel_length': 2.197319434102755},
#    'UD_Ukrainian-IU': {'num_trees': 1747,
#     'avg_depth': 1.990269032627361,
#     'avg_size': 6.476244991413853,
#     'avg_rel_length': 1.8129750751281597},
#    'UD_Upper_Sorbian-UFAL': {'num_trees': 2,
#     'avg_depth': 1.5,
#     'avg_size': 6.5,
#     'avg_rel_length': 1.6923076923076923},
#    'UD_Urdu-UDTB': {'num_trees': 144,
#     'avg_depth': 2.5694444444444446,
#     'avg_size': 9.95138888888889,
#     'avg_rel_length': 2.0237264480111654},
#    'UD_Uyghur-UDT': {'num_trees': 833,
#     'avg_depth': 2.3097238895558223,
#     'avg_size': 7.393757503001201,
#     'avg_rel_length': 1.662445202143205},
#    'UD_Vietnamese-VTB': {'num_trees': 386,
#     'avg_depth': 2.16839378238342,
#     'avg_size': 7.7642487046632125,
#     'avg_rel_length': 1.9606272939606273},
#    'UD_Welsh-CCG': {'num_trees': 71,
#     'avg_depth': 2.732394366197183,
#     'avg_size': 8.732394366197184,
#     'avg_rel_length': 2.111290322580645},
#    'UD_Western_Armenian-ArmTDP': {'num_trees': 174,
#     'avg_depth': 1.867816091954023,
#     'avg_size': 6.7988505747126435,
#     'avg_rel_length': 1.816568047337278},
#    'UD_Wolof-WTB': {'num_trees': 156,
#     'avg_depth': 2.1025641025641026,
#     'avg_size': 7.42948717948718,
#     'avg_rel_length': 1.8731665228645384}},
#   'test': {'UD_Afrikaans-AfriBooms': {'num_trees': 38,
#     'avg_depth': 2.5789473684210527,
#     'avg_size': 10.157894736842104,
#     'avg_rel_length': 2.3704663212435233},
#    'UD_Akkadian-PISANDUB': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Akkadian-RIAO': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Akuntsu-TuDeT': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Albanian-TSA': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Amharic-ATT': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Ancient_Greek-Perseus': {'num_trees': 629,
#     'avg_depth': 2.537360890302067,
#     'avg_size': 9.267090620031796,
#     'avg_rel_length': 2.4777834963115457},
#    'UD_Ancient_Greek-PROIEL': {'num_trees': 664,
#     'avg_depth': 2.4894578313253013,
#     'avg_size': 7.760542168674699,
#     'avg_rel_length': 2.0285270716087718},
#    'UD_Apurina-UFPA': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Arabic-NYUAD': {'num_trees': 204,
#     'avg_depth': 2.127450980392157,
#     'avg_size': 7.205882352941177,
#     'avg_rel_length': 1.9700680272108844},
#    'UD_Arabic-PADT': {'num_trees': 87,
#     'avg_depth': 2.7241379310344827,
#     'avg_size': 6.505747126436781,
#     'avg_rel_length': 1.607773851590106},
#    'UD_Arabic-PUD': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Armenian-ArmTDP': {'num_trees': 82,
#     'avg_depth': 2.2560975609756095,
#     'avg_size': 7.414634146341464,
#     'avg_rel_length': 1.9720394736842106},
#    'UD_Assyrian-AS': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Bambara-CRB': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Basque-BDT': {'num_trees': 922,
#     'avg_depth': 2.5477223427331888,
#     'avg_size': 8.996746203904555,
#     'avg_rel_length': 2.137552742616034},
#    'UD_Beja-NSC': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Belarusian-HSE': {'num_trees': 645,
#     'avg_depth': 2.2930232558139534,
#     'avg_size': 7.170542635658915,
#     'avg_rel_length': 1.9065945945945946},
#    'UD_Bhojpuri-BHTB': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Breton-KEB': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Bulgarian-BTB': {'num_trees': 608,
#     'avg_depth': 2.5871710526315788,
#     'avg_size': 8.40625,
#     'avg_rel_length': 2.105067501467423},
#    'UD_Buryat-BDT': {'num_trees': 132,
#     'avg_depth': 1.8333333333333333,
#     'avg_size': 5.2272727272727275,
#     'avg_rel_length': 1.2521739130434784},
#    'UD_Cantonese-HK': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Catalan-AnCora': {'num_trees': 198,
#     'avg_depth': 2.5707070707070705,
#     'avg_size': 10.262626262626263,
#     'avg_rel_length': 2.2229330708661417},
#    'UD_Chinese-CFL': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Chinese-GSD': {'num_trees': 67,
#     'avg_depth': 3.1492537313432836,
#     'avg_size': 12.432835820895523,
#     'avg_rel_length': 2.5402160864345738},
#    'UD_Chinese-GSDSimp': {'num_trees': 68,
#     'avg_depth': 3.1323529411764706,
#     'avg_size': 12.470588235294118,
#     'avg_rel_length': 2.544811320754717},
#    'UD_Chinese-HK': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Chinese-PUD': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Chukchi-HSE': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Classical_Chinese-Kyoto': {'num_trees': 4386,
#     'avg_depth': 1.8987688098495212,
#     'avg_size': 4.702234382124943,
#     'avg_rel_length': 1.30716640806827},
#    'UD_Coptic-Scriptorium': {'num_trees': 40,
#     'avg_depth': 2.7,
#     'avg_size': 10.875,
#     'avg_rel_length': 2.2758620689655173},
#    'UD_Croatian-SET': {'num_trees': 241,
#     'avg_depth': 2.809128630705394,
#     'avg_size': 9.979253112033195,
#     'avg_rel_length': 2.1725571725571724},
#    'UD_Czech-CAC': {'num_trees': 294,
#     'avg_depth': 2.6700680272108843,
#     'avg_size': 9.051020408163266,
#     'avg_rel_length': 2.2145809845922586},
#    'UD_Czech-CLTT': {'num_trees': 27,
#     'avg_depth': 0.8518518518518519,
#     'avg_size': 2.4814814814814814,
#     'avg_rel_length': 1.1791044776119404},
#    'UD_Czech-FicTree': {'num_trees': 833,
#     'avg_depth': 2.1536614645858343,
#     'avg_size': 7.90516206482593,
#     'avg_rel_length': 2.284738041002278},
#    'UD_Czech-PDT': {'num_trees': 5081,
#     'avg_depth': 2.671324542412911,
#     'avg_size': 8.974020862035033,
#     'avg_rel_length': 2.3075202315941836},
#    'UD_Czech-PUD': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Danish-DDT': {'num_trees': 213,
#     'avg_depth': 2.3098591549295775,
#     'avg_size': 8.295774647887324,
#     'avg_rel_length': 2.216185625353707},
#    'UD_Dutch-Alpino': {'num_trees': 217,
#     'avg_depth': 2.557603686635945,
#     'avg_size': 10.050691244239632,
#     'avg_rel_length': 2.474094452086199},
#    'UD_Dutch-LassySmall': {'num_trees': 503,
#     'avg_depth': 1.7495029821073558,
#     'avg_size': 5.73558648111332,
#     'avg_rel_length': 1.8852686308492201},
#    'UD_English-ESL': {'num_trees': 145,
#     'avg_depth': 2.6482758620689655,
#     'avg_size': 10.427586206896551,
#     'avg_rel_length': 2.3439153439153437},
#    'UD_English-EWT': {'num_trees': 1386,
#     'avg_depth': 1.8073593073593073,
#     'avg_size': 6.32972582972583,
#     'avg_rel_length': 2.0648580873133477},
#    'UD_English-GUM': {'num_trees': 352,
#     'avg_depth': 2.002840909090909,
#     'avg_size': 7.107954545454546,
#     'avg_rel_length': 2.0743405275779376},
#    'UD_English-GUMReddit': {'num_trees': 39,
#     'avg_depth': 1.6923076923076923,
#     'avg_size': 6.256410256410256,
#     'avg_rel_length': 2.0},
#    'UD_English-LinES': {'num_trees': 415,
#     'avg_depth': 2.3012048192771086,
#     'avg_size': 8.39277108433735,
#     'avg_rel_length': 2.124605225380419},
#    'UD_English-ParTUT': {'num_trees': 17,
#     'avg_depth': 2.235294117647059,
#     'avg_size': 9.117647058823529,
#     'avg_rel_length': 2.1354838709677417},
#    'UD_English-Pronouns': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_English-PUD': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Erzya-JR': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Estonian-EDT': {'num_trees': 1816,
#     'avg_depth': 2.344713656387665,
#     'avg_size': 8.619493392070485,
#     'avg_rel_length': 2.351050916757171},
#    'UD_Estonian-EWT': {'num_trees': 508,
#     'avg_depth': 2.0570866141732282,
#     'avg_size': 7.403543307086614,
#     'avg_rel_length': 2.1590002658867324},
#    'UD_Faroese-FarPaHC': {'num_trees': 27,
#     'avg_depth': 2.5925925925925926,
#     'avg_size': 8.777777777777779,
#     'avg_rel_length': 1.4936708860759493},
#    'UD_Faroese-OFT': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Finnish-FTB': {'num_trees': 1545,
#     'avg_depth': 2.3928802588996763,
#     'avg_size': 7.0504854368932035,
#     'avg_rel_length': 1.531809418892867},
#    'UD_Finnish-OOD': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Finnish-PUD': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Finnish-TDT': {'num_trees': 921,
#     'avg_depth': 2.469055374592834,
#     'avg_size': 8.478827361563518,
#     'avg_rel_length': 2.1667306953515175},
#    'UD_French-FQB': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_French-FTB': {'num_trees': 471,
#     'avg_depth': 2.1910828025477707,
#     'avg_size': 8.127388535031848,
#     'avg_rel_length': 2.184691745036573},
#    'UD_French-GSD': {'num_trees': 113,
#     'avg_depth': 2.8053097345132745,
#     'avg_size': 10.557522123893806,
#     'avg_rel_length': 2.269069572506287},
#    'UD_French-ParTUT': {'num_trees': 3,
#     'avg_depth': 2.3333333333333335,
#     'avg_size': 8.666666666666666,
#     'avg_rel_length': 1.9230769230769231},
#    'UD_French-PUD': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_French-Sequoia': {'num_trees': 137,
#     'avg_depth': 1.7664233576642336,
#     'avg_size': 5.569343065693431,
#     'avg_rel_length': 1.9213630406290956},
#    'UD_French-Spoken': {'num_trees': 367,
#     'avg_depth': 1.978201634877384,
#     'avg_size': 6.114441416893733,
#     'avg_rel_length': 1.697415329768271},
#    'UD_Frisian_Dutch-Fame': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Galician-CTG': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Galician-TreeGal': {'num_trees': 76,
#     'avg_depth': 1.986842105263158,
#     'avg_size': 6.276315789473684,
#     'avg_rel_length': 1.7840670859538783},
#    'UD_German-GSD': {'num_trees': 480,
#     'avg_depth': 2.5145833333333334,
#     'avg_size': 9.929166666666667,
#     'avg_rel_length': 2.535249685270667},
#    'UD_German-HDT': {'num_trees': 10468,
#     'avg_depth': 2.838460068781047,
#     'avg_size': 11.639568207871609,
#     'avg_rel_length': 2.849962656861699},
#    'UD_German-LIT': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_German-PUD': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Gothic-PROIEL': {'num_trees': 710,
#     'avg_depth': 2.1507042253521127,
#     'avg_size': 6.471830985915493,
#     'avg_rel_length': 1.7473340587595212},
#    'UD_Greek-GDT': {'num_trees': 99,
#     'avg_depth': 1.9898989898989898,
#     'avg_size': 7.101010101010101,
#     'avg_rel_length': 1.9189189189189189},
#    'UD_Guajajara-TuDeT': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Hebrew-HTB': {'num_trees': 71,
#     'avg_depth': 2.732394366197183,
#     'avg_size': 9.43661971830986,
#     'avg_rel_length': 2.074626865671642},
#    'UD_Hindi-HDTB': {'num_trees': 499,
#     'avg_depth': 2.8456913827655312,
#     'avg_size': 12.050100200400802,
#     'avg_rel_length': 2.3941460169632465},
#    'UD_Hindi-PUD': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Hindi_English-HIENCS': {'num_trees': 53,
#     'avg_depth': 2.849056603773585,
#     'avg_size': 11.452830188679245,
#     'avg_rel_length': 2.3113673805601316},
#    'UD_Hungarian-Szeged': {'num_trees': 44,
#     'avg_depth': 2.1136363636363638,
#     'avg_size': 7.636363636363637,
#     'avg_rel_length': 1.8928571428571428},
#    'UD_Icelandic-IcePaHC': {'num_trees': 1618,
#     'avg_depth': 2.888751545117429,
#     'avg_size': 10.441285537700866,
#     'avg_rel_length': 1.838818515449272},
#    'UD_Icelandic-Modern': {'num_trees': 530,
#     'avg_depth': 4.533962264150944,
#     'avg_size': 20.462264150943398,
#     'avg_rel_length': 2.5029967727063163},
#    'UD_Icelandic-PUD': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Indonesian-CSUI': {'num_trees': 8,
#     'avg_depth': 3.0,
#     'avg_size': 9.125,
#     'avg_rel_length': 2.219178082191781},
#    'UD_Indonesian-GSD': {'num_trees': 141,
#     'avg_depth': 3.078014184397163,
#     'avg_size': 10.212765957446809,
#     'avg_rel_length': 2.0347222222222223},
#    'UD_Indonesian-PUD': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Irish-IDT': {'num_trees': 145,
#     'avg_depth': 2.2413793103448274,
#     'avg_size': 7.165517241379311,
#     'avg_rel_length': 2.0567853705486043},
#    'UD_Irish-TwittIrish': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Italian-ISDT': {'num_trees': 196,
#     'avg_depth': 2.683673469387755,
#     'avg_size': 9.5,
#     'avg_rel_length': 2.10687432867884},
#    'UD_Italian-ParTUT': {'num_trees': 12,
#     'avg_depth': 2.0833333333333335,
#     'avg_size': 9.25,
#     'avg_rel_length': 2.126126126126126},
#    'UD_Italian-PoSTWITA': {'num_trees': 189,
#     'avg_depth': 2.3915343915343916,
#     'avg_size': 10.767195767195767,
#     'avg_rel_length': 2.617690417690418},
#    'UD_Italian-PUD': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Italian-TWITTIRO': {'num_trees': 6,
#     'avg_depth': 2.3333333333333335,
#     'avg_size': 12.0,
#     'avg_rel_length': 2.8333333333333335},
#    'UD_Italian-Valico': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Italian-VIT': {'num_trees': 298,
#     'avg_depth': 2.4060402684563758,
#     'avg_size': 8.75503355704698,
#     'avg_rel_length': 2.247604446147949},
#    'UD_Japanese-BCCWJ': {'num_trees': 3940,
#     'avg_depth': 2.285532994923858,
#     'avg_size': 8.963197969543147,
#     'avg_rel_length': 2.069687101798103},
#    'UD_Japanese-GSD': {'num_trees': 144,
#     'avg_depth': 2.4791666666666665,
#     'avg_size': 9.333333333333334,
#     'avg_rel_length': 1.9367559523809523},
#    'UD_Japanese-Modern': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Japanese-PUD': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Kaapor-TuDeT': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Kangri-KDTB': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Karelian-KKPP': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Kazakh-KTB': {'num_trees': 110,
#     'avg_depth': 1.9363636363636363,
#     'avg_size': 6.390909090909091,
#     'avg_rel_length': 1.4395448079658606},
#    'UD_Khunsari-AHA': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Kiche-IU': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Komi_Permyak-UH': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Komi_Zyrian-IKDP': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Komi_Zyrian-Lattice': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Korean-GSD': {'num_trees': 620,
#     'avg_depth': 2.732258064516129,
#     'avg_size': 7.291935483870968,
#     'avg_rel_length': 1.7153284671532847},
#    'UD_Korean-Kaist': {'num_trees': 1404,
#     'avg_depth': 3.17022792022792,
#     'avg_size': 9.27991452991453,
#     'avg_rel_length': 1.8248522526671271},
#    'UD_Korean-PUD': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Kurmanji-MG': {'num_trees': 34,
#     'avg_depth': 2.323529411764706,
#     'avg_size': 8.294117647058824,
#     'avg_rel_length': 1.9148936170212767},
#    'UD_Latin-ITTB': {'num_trees': 1273,
#     'avg_depth': 2.3401413982717987,
#     'avg_size': 8.369992144540456,
#     'avg_rel_length': 2.329422806194275},
#    'UD_Latin-LLCT': {'num_trees': 521,
#     'avg_depth': 4.153550863723608,
#     'avg_size': 11.27063339731286,
#     'avg_rel_length': 2.5233310626703},
#    'UD_Latin-Perseus': {'num_trees': 496,
#     'avg_depth': 2.1391129032258065,
#     'avg_size': 6.931451612903226,
#     'avg_rel_length': 2.0357766143106457},
#    'UD_Latin-PROIEL': {'num_trees': 877,
#     'avg_depth': 2.3192702394526794,
#     'avg_size': 6.857468643101482,
#     'avg_rel_length': 1.855171267043565},
#    'UD_Latin-UDante': {'num_trees': 19,
#     'avg_depth': 2.263157894736842,
#     'avg_size': 7.578947368421052,
#     'avg_rel_length': 1.8958333333333333},
#    'UD_Latvian-LVTB': {'num_trees': 1078,
#     'avg_depth': 2.1669758812615956,
#     'avg_size': 7.530612244897959,
#     'avg_rel_length': 2.125277161862528},
#    'UD_Lithuanian-ALKSNIS': {'num_trees': 251,
#     'avg_depth': 2.3266932270916336,
#     'avg_size': 6.780876494023905,
#     'avg_rel_length': 1.9330199764982374},
#    'UD_Lithuanian-HSE': {'num_trees': 2,
#     'avg_depth': 2.5,
#     'avg_size': 7.5,
#     'avg_rel_length': 1.8666666666666667},
#    'UD_Livvi-KKPP': {'num_trees': 7,
#     'avg_depth': 1.8571428571428572,
#     'avg_size': 6.571428571428571,
#     'avg_rel_length': 1.673913043478261},
#    'UD_Low_Saxon-LSDC': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Makurap-TuDeT': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Maltese-MUDT': {'num_trees': 100,
#     'avg_depth': 2.11,
#     'avg_size': 6.86,
#     'avg_rel_length': 1.9314868804664722},
#    'UD_Manx-Cadhan': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Marathi-UFAL': {'num_trees': 31,
#     'avg_depth': 1.967741935483871,
#     'avg_size': 6.354838709677419,
#     'avg_rel_length': 1.5888324873096447},
#    'UD_Mbya_Guarani-Dooley': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Mbya_Guarani-Thomas': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Moksha-JR': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Munduruku-TuDeT': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Naija-NSC': {'num_trees': 610,
#     'avg_depth': 1.980327868852459,
#     'avg_size': 7.981967213114754,
#     'avg_rel_length': 2.1942904087081536},
#    'UD_Nayini-AHA': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_North_Sami-Giella': {'num_trees': 474,
#     'avg_depth': 2.149789029535865,
#     'avg_size': 7.59915611814346,
#     'avg_rel_length': 1.977234869516935},
#    'UD_Norwegian-Bokmaal': {'num_trees': 1036,
#     'avg_depth': 2.5048262548262548,
#     'avg_size': 9.156370656370656,
#     'avg_rel_length': 2.265022137887413},
#    'UD_Norwegian-Nynorsk': {'num_trees': 716,
#     'avg_depth': 2.4064245810055866,
#     'avg_size': 8.572625698324023,
#     'avg_rel_length': 2.2469859889214727},
#    'UD_Norwegian-NynorskLIA': {'num_trees': 611,
#     'avg_depth': 1.6317512274959083,
#     'avg_size': 5.590834697217676,
#     'avg_rel_length': 1.9408665105386418},
#    'UD_Old_Church_Slavonic-PROIEL': {'num_trees': 873,
#     'avg_depth': 2.011454753722795,
#     'avg_size': 6.1993127147766325,
#     'avg_rel_length': 1.6869918699186992},
#    'UD_Old_East_Slavic-RNC': {'num_trees': 69,
#     'avg_depth': 2.1739130434782608,
#     'avg_size': 6.608695652173913,
#     'avg_rel_length': 1.8267543859649122},
#    'UD_Old_East_Slavic-TOROT': {'num_trees': 1453,
#     'avg_depth': 2.1307639366827256,
#     'avg_size': 6.412250516173434,
#     'avg_rel_length': 1.685199098422239},
#    'UD_Old_French-SRCMF': {'num_trees': 1578,
#     'avg_depth': 2.1958174904942966,
#     'avg_size': 6.633079847908745,
#     'avg_rel_length': 1.7296264450176746},
#    'UD_Old_Turkish-Tonqq': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Persian-PerDT': {'num_trees': 744,
#     'avg_depth': 2.8333333333333335,
#     'avg_size': 10.299731182795698,
#     'avg_rel_length': 2.3484275088085607},
#    'UD_Persian-Seraji': {'num_trees': 92,
#     'avg_depth': 2.597826086956522,
#     'avg_size': 9.304347826086957,
#     'avg_rel_length': 2.3130841121495327},
#    'UD_Polish-LFG': {'num_trees': 1607,
#     'avg_depth': 2.093341630367144,
#     'avg_size': 7.037958929682638,
#     'avg_rel_length': 1.9511936339522546},
#    'UD_Polish-PDB': {'num_trees': 1233,
#     'avg_depth': 2.673154906731549,
#     'avg_size': 8.892944038929441,
#     'avg_rel_length': 2.1629730962152305},
#    'UD_Polish-PUD': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Portuguese-Bosque': {'num_trees': 145,
#     'avg_depth': 2.3793103448275863,
#     'avg_size': 7.862068965517241,
#     'avg_rel_length': 2.0359649122807015},
#    'UD_Portuguese-GSD': {'num_trees': 234,
#     'avg_depth': 2.8076923076923075,
#     'avg_size': 10.675213675213675,
#     'avg_rel_length': 2.2594075260208166},
#    'UD_Portuguese-PUD': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Romanian-ArT': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Romanian-Nonstandard': {'num_trees': 438,
#     'avg_depth': 2.5251141552511416,
#     'avg_size': 9.616438356164384,
#     'avg_rel_length': 2.434235517568851},
#    'UD_Romanian-RRT': {'num_trees': 116,
#     'avg_depth': 2.836206896551724,
#     'avg_size': 10.922413793103448,
#     'avg_rel_length': 2.3338595106550906},
#    'UD_Romanian-SiMoNERo': {'num_trees': 6,
#     'avg_depth': 2.8333333333333335,
#     'avg_size': 10.833333333333334,
#     'avg_rel_length': 2.1384615384615384},
#    'UD_Russian-GSD': {'num_trees': 181,
#     'avg_depth': 2.723756906077348,
#     'avg_size': 8.707182320441989,
#     'avg_rel_length': 2.0310913705583755},
#    'UD_Russian-PUD': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Russian-SynTagRus': {'num_trees': 3011,
#     'avg_depth': 2.74061773497177,
#     'avg_size': 9.581534373962139,
#     'avg_rel_length': 2.2472790294627383},
#    'UD_Russian-Taiga': {'num_trees': 620,
#     'avg_depth': 2.304838709677419,
#     'avg_size': 7.412903225806452,
#     'avg_rel_length': 2.045474325500435},
#    'UD_Sanskrit-UFAL': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Sanskrit-Vedic': {'num_trees': 1285,
#     'avg_depth': 2.0249027237354085,
#     'avg_size': 5.414007782101168,
#     'avg_rel_length': 1.682765559867759},
#    'UD_Scottish_Gaelic-ARCOSG': {'num_trees': 206,
#     'avg_depth': 2.174757281553398,
#     'avg_size': 6.092233009708738,
#     'avg_rel_length': 1.6796812749003984},
#    'UD_Serbian-SET': {'num_trees': 78,
#     'avg_depth': 2.6153846153846154,
#     'avg_size': 9.08974358974359,
#     'avg_rel_length': 2.0197461212976022},
#    'UD_Skolt_Sami-Giellagas': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Slovak-SNK': {'num_trees': 590,
#     'avg_depth': 2.247457627118644,
#     'avg_size': 7.071186440677966,
#     'avg_rel_length': 1.9465484180249282},
#    'UD_Slovenian-SSJ': {'num_trees': 303,
#     'avg_depth': 2.5346534653465347,
#     'avg_size': 9.432343234323433,
#     'avg_rel_length': 2.254373687893632},
#    'UD_Slovenian-SST': {'num_trees': 781,
#     'avg_depth': 1.1869398207426376,
#     'avg_size': 4.444302176696543,
#     'avg_rel_length': 1.679919331604725},
#    'UD_Soi-AHA': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_South_Levantine_Arabic-MADAR': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Spanish-AnCora': {'num_trees': 289,
#     'avg_depth': 2.4948096885813147,
#     'avg_size': 9.598615916955017,
#     'avg_rel_length': 2.245493871665465},
#    'UD_Spanish-GSD': {'num_trees': 94,
#     'avg_depth': 2.9574468085106385,
#     'avg_size': 11.063829787234043,
#     'avg_rel_length': 2.2759615384615386},
#    'UD_Spanish-PUD': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Swedish-LinES': {'num_trees': 435,
#     'avg_depth': 2.2367816091954023,
#     'avg_size': 8.360919540229885,
#     'avg_rel_length': 2.152048391531482},
#    'UD_Swedish-PUD': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Swedish-Talbanken': {'num_trees': 480,
#     'avg_depth': 2.3583333333333334,
#     'avg_size': 8.427083333333334,
#     'avg_rel_length': 2.1599505562422743},
#    'UD_Swedish_Sign_Language-SSLC': {'num_trees': 16,
#     'avg_depth': 1.625,
#     'avg_size': 5.1875,
#     'avg_rel_length': 1.5301204819277108},
#    'UD_Swiss_German-UZH': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Tagalog-TRG': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Tagalog-Ugnayan': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Tamil-MWTT': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Tamil-TTB': {'num_trees': 20,
#     'avg_depth': 2.75,
#     'avg_size': 8.65,
#     'avg_rel_length': 1.7341040462427746},
#    'UD_Telugu-MTG': {'num_trees': 141,
#     'avg_depth': 1.5390070921985815,
#     'avg_size': 4.74468085106383,
#     'avg_rel_length': 1.194319880418535},
#    'UD_Thai-PUD': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Tupinamba-TuDeT': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Turkish-BOUN': {'num_trees': 596,
#     'avg_depth': 2.3926174496644297,
#     'avg_size': 7.098993288590604,
#     'avg_rel_length': 1.6922713306546915},
#    'UD_Turkish-FrameNet': {'num_trees': 187,
#     'avg_depth': 2.2941176470588234,
#     'avg_size': 6.657754010695188,
#     'avg_rel_length': 1.3975903614457832},
#    'UD_Turkish-GB': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Turkish-IMST': {'num_trees': 665,
#     'avg_depth': 2.1593984962406014,
#     'avg_size': 6.2706766917293235,
#     'avg_rel_length': 1.5366906474820143},
#    'UD_Turkish-Kenet': {'num_trees': 1227,
#     'avg_depth': 2.893235533822331,
#     'avg_size': 9.179299103504482,
#     'avg_rel_length': 1.8821805913167007},
#    'UD_Turkish-Penn': {'num_trees': 465,
#     'avg_depth': 2.533333333333333,
#     'avg_size': 7.694623655913978,
#     'avg_rel_length': 1.8605366126327558},
#    'UD_Turkish-PUD': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Turkish-Tourism': {'num_trees': 2165,
#     'avg_depth': 1.7390300230946882,
#     'avg_size': 4.534411085450347,
#     'avg_rel_length': 1.060405419170826},
#    'UD_Turkish_German-SAGT': {'num_trees': 200,
#     'avg_depth': 2.025,
#     'avg_size': 8.12,
#     'avg_rel_length': 2.2007389162561575},
#    'UD_Ukrainian-IU': {'num_trees': 355,
#     'avg_depth': 2.1943661971830988,
#     'avg_size': 7.011267605633803,
#     'avg_rel_length': 1.9200482121333868},
#    'UD_Upper_Sorbian-UFAL': {'num_trees': 11,
#     'avg_depth': 1.6363636363636365,
#     'avg_size': 6.909090909090909,
#     'avg_rel_length': 1.7105263157894737},
#    'UD_Urdu-UDTB': {'num_trees': 58,
#     'avg_depth': 2.7413793103448274,
#     'avg_size': 11.03448275862069,
#     'avg_rel_length': 2.0828125},
#    'UD_Uyghur-UDT': {'num_trees': 501,
#     'avg_depth': 2.3512974051896207,
#     'avg_size': 7.574850299401198,
#     'avg_rel_length': 1.6885375494071146},
#    'UD_Vietnamese-VTB': {'num_trees': 228,
#     'avg_depth': 2.258771929824561,
#     'avg_size': 8.153508771929825,
#     'avg_rel_length': 2.038192576654115},
#    'UD_Warlpiri-UFAL': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Welsh-CCG': {'num_trees': 193,
#     'avg_depth': 2.38860103626943,
#     'avg_size': 7.450777202072539,
#     'avg_rel_length': 1.9401947148817802},
#    'UD_Western_Armenian-ArmTDP': {'num_trees': 102,
#     'avg_depth': 2.127450980392157,
#     'avg_size': 7.666666666666667,
#     'avg_rel_length': 2.0217391304347827},
#    'UD_Wolof-WTB': {'num_trees': 78,
#     'avg_depth': 2.1538461538461537,
#     'avg_size': 7.653846153846154,
#     'avg_rel_length': 1.9614740368509214},
#    'UD_Yoruba-YTB': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0},
#    'UD_Yupik-SLI': {'num_trees': 0,
#     'avg_depth': 0,
#     'avg_size': 0,
#     'avg_rel_length': 0}}},
#  'nonleaky': {'train': {'UD_Afrikaans-AfriBooms': {'num_trees': 1256,
#     'avg_depth': 5.359076433121019,
#     'avg_size': 26.503184713375795,
#     'avg_rel_length': 3.2448329728430667},
#    'UD_Ancient_Greek-Perseus': {'num_trees': 6364,
#     'avg_depth': 4.046668761785041,
#     'avg_size': 18.897705845380266,
#     'avg_rel_length': 3.59099488629277},
#    'UD_Ancient_Greek-PROIEL': {'num_trees': 7282,
#     'avg_depth': 4.292090085141445,
#     'avg_size': 19.108486679483658,
#     'avg_rel_length': 2.957714088596315},
#    'UD_Arabic-NYUAD': {'num_trees': 14719,
#     'avg_depth': 7.618588219308377,
#     'avg_size': 39.70813234594741,
#     'avg_rel_length': 4.152808385118673},
#    'UD_Arabic-PADT': {'num_trees': 5604,
#     'avg_depth': 7.614739471805853,
#     'avg_size': 39.52926481084939,
#     'avg_rel_length': 4.08023582307852},
#    'UD_Armenian-ArmTDP': {'num_trees': 1644,
#     'avg_depth': 4.697080291970803,
#     'avg_size': 24.369221411192214,
#     'avg_rel_length': 3.7073359458852306},
#    'UD_Basque-BDT': {'num_trees': 3045,
#     'avg_depth': 4.320197044334975,
#     'avg_size': 17.494909688013138,
#     'avg_rel_length': 3.17324297942634},
#    'UD_Belarusian-HSE': {'num_trees': 11367,
#     'avg_depth': 4.3583179378903845,
#     'avg_size': 17.956013020146038,
#     'avg_rel_length': 2.9678941334404674},
# ...
#     'avg_rel_length': 2.833361847733105},
#    'UD_Japanese-Modern': {'num_trees': 822,
#     'avg_depth': 4.294403892944039,
#     'avg_size': 17.632603406326034,
#     'avg_rel_length': 2.684421139781979},
#    'UD_Japanese-PUD': {'num_trees': 1000,
#     'avg_depth': 4.916,
#     'avg_size': 28.788,
#     'avg_rel_length': 2.9026677782409336},
#    'UD_Kaapor-TuDeT': {'num_trees': 61,
#     'avg_depth': 1.2950819672131149,
#     'avg_size': 3.9344262295081966,
#     'avg_rel_length': 1.275},
#    'UD_Kangri-KDTB': {'num_trees': 288,
#     'avg_depth': 2.3993055555555554,
#     'avg_size': 8.729166666666666,
#     'avg_rel_length': 1.9534606205250598},
#    'UD_Karelian-KKPP': {'num_trees': 228,
#     'avg_depth': 3.3640350877192984,
#     'avg_size': 13.570175438596491,
#     'avg_rel_length': 2.6994182288299937},
#    'UD_Kazakh-KTB': {'num_trees': 937,
#     'avg_depth': 3.0533617929562435,
#     'avg_size': 9.92956243329776,
#     'avg_rel_length': 2.2062553740326742},
#    'UD_Khunsari-AHA': {'num_trees': 10,
#     'avg_depth': 2.6,
#     'avg_size': 7.4,
#     'avg_rel_length': 1.7297297297297298},
#    'UD_Kiche-IU': {'num_trees': 1435,
#     'avg_depth': 2.3588850174216027,
#     'avg_size': 6.977700348432056,
#     'avg_rel_length': 1.9531608908419056},
#    'UD_Komi_Permyak-UH': {'num_trees': 81,
#     'avg_depth': 2.6296296296296298,
#     'avg_size': 10.358024691358025,
#     'avg_rel_length': 2.532777115613826},
#    'UD_Komi_Zyrian-IKDP': {'num_trees': 214,
#     'avg_depth': 2.7990654205607477,
#     'avg_size': 10.789719626168225,
#     'avg_rel_length': 2.5262018189692506},
#    'UD_Komi_Zyrian-Lattice': {'num_trees': 658,
#     'avg_depth': 2.8434650455927053,
#     'avg_size': 12.17629179331307,
#     'avg_rel_length': 2.700698951572641},
#    'UD_Korean-GSD': {'num_trees': 369,
#     'avg_depth': 5.21409214092141,
#     'avg_size': 19.392953929539296,
#     'avg_rel_length': 2.9446618222470655},
#    'UD_Korean-Kaist': {'num_trees': 883,
#     'avg_depth': 5.098527746319366,
#     'avg_size': 17.369195922989807,
#     'avg_rel_length': 2.5717545804264197},
#    'UD_Korean-PUD': {'num_trees': 1000,
#     'avg_depth': 4.906,
#     'avg_size': 16.584,
#     'avg_rel_length': 2.5876145682585623},
#    'UD_Kurmanji-MG': {'num_trees': 700,
#     'avg_depth': 3.3242857142857143,
#     'avg_size': 13.90857142857143,
#     'avg_rel_length': 2.8547658175842234},
#    'UD_Latin-ITTB': {'num_trees': 828,
#     'avg_depth': 4.624396135265701,
#     'avg_size': 23.17270531400966,
#     'avg_rel_length': 3.53713451816334},
#    'UD_Latin-LLCT': {'num_trees': 363,
#     'avg_depth': 5.771349862258953,
#     'avg_size': 50.15702479338843,
#     'avg_rel_length': 4.881474158290767},
#    'UD_Latin-Perseus': {'num_trees': 443,
#     'avg_depth': 4.036117381489842,
#     'avg_size': 16.966139954853272,
#     'avg_rel_length': 3.512240553485897},
#    'UD_Latin-PROIEL': {'num_trees': 383,
#     'avg_depth': 4.934725848563969,
#     'avg_size': 21.088772845953002,
#     'avg_rel_length': 3.163798440014857},
#    'UD_Latin-UDante': {'num_trees': 400,
#     'avg_depth': 4.995,
#     'avg_size': 33.2575,
#     'avg_rel_length': 4.344659099451252},
#    'UD_Latvian-LVTB': {'num_trees': 958,
#     'avg_depth': 4.960334029227558,
#     'avg_size': 23.156576200417536,
#     'avg_rel_length': 3.3923999278759465},
#    'UD_Lithuanian-ALKSNIS': {'num_trees': 433,
#     'avg_depth': 4.882217090069284,
#     'avg_size': 21.117782909930717,
#     'avg_rel_length': 3.395669291338583},
#    'UD_Lithuanian-HSE': {'num_trees': 53,
#     'avg_depth': 4.886792452830188,
#     'avg_size': 19.71698113207547,
#     'avg_rel_length': 3.2344497607655502},
#    'UD_Livvi-KKPP': {'num_trees': 99,
#     'avg_depth': 3.525252525252525,
#     'avg_size': 14.565656565656566,
#     'avg_rel_length': 2.482662968099861},
#    'UD_Low_Saxon-LSDC': {'num_trees': 36,
#     'avg_depth': 4.611111111111111,
#     'avg_size': 31.166666666666668,
#     'avg_rel_length': 4.3431372549019605},
#    'UD_Makurap-TuDeT': {'num_trees': 31,
#     'avg_depth': 1.7741935483870968,
#     'avg_size': 4.709677419354839,
#     'avg_rel_length': 1.2534246575342465},
#    'UD_Maltese-MUDT': {'num_trees': 418,
#     'avg_depth': 5.411483253588517,
#     'avg_size': 24.849282296650717,
#     'avg_rel_length': 3.305189178781169},
#    'UD_Manx-Cadhan': {'num_trees': 2319,
#     'avg_depth': 2.697714532125916,
#     'avg_size': 8.896075894782234,
#     'avg_rel_length': 2.536500242365487},
#    'UD_Marathi-UFAL': {'num_trees': 16,
#     'avg_depth': 3.625,
#     'avg_size': 13.4375,
#     'avg_rel_length': 2.372093023255814},
#    'UD_Mbya_Guarani-Dooley': {'num_trees': 1046,
#     'avg_depth': 2.5592734225621414,
#     'avg_size': 11.253346080305928,
#     'avg_rel_length': 2.4437176110780734},
#    'UD_Mbya_Guarani-Thomas': {'num_trees': 98,
#     'avg_depth': 2.704081632653061,
#     'avg_size': 13.448979591836734,
#     'avg_rel_length': 2.5880121396054627},
#    'UD_Moksha-JR': {'num_trees': 313,
#     'avg_depth': 2.571884984025559,
#     'avg_size': 8.94888178913738,
#     'avg_rel_length': 2.202784719742949},
#    'UD_Munduruku-TuDeT': {'num_trees': 109,
#     'avg_depth': 1.9174311926605505,
#     'avg_size': 4.724770642201835,
#     'avg_rel_length': 1.254368932038835},
#    'UD_Naija-NSC': {'num_trees': 362,
#     'avg_depth': 4.726519337016574,
#     'avg_size': 26.18232044198895,
#     'avg_rel_length': 4.116796792572273},
#    'UD_Nayini-AHA': {'num_trees': 10,
#     'avg_depth': 2.7,
#     'avg_size': 7.8,
#     'avg_rel_length': 1.7820512820512822},
#    'UD_North_Sami-Giella': {'num_trees': 391,
#     'avg_depth': 3.8005115089514065,
#     'avg_size': 16.388746803069054,
#     'avg_rel_length': 3.0265293383270913},
#    'UD_Norwegian-Bokmaal': {'num_trees': 903,
#     'avg_depth': 4.789590254706534,
#     'avg_size': 22.67995570321152,
#     'avg_rel_length': 3.291748046875},
#    'UD_Norwegian-Nynorsk': {'num_trees': 795,
#     'avg_depth': 4.983647798742139,
#     'avg_size': 23.440251572327043,
#     'avg_rel_length': 3.309686074590824},
#    'UD_Norwegian-NynorskLIA': {'num_trees': 346,
#     'avg_depth': 4.005780346820809,
#     'avg_size': 19.14450867052023,
#     'avg_rel_length': 3.129981884057971},
#    'UD_Old_Church_Slavonic-PROIEL': {'num_trees': 268,
#     'avg_depth': 4.082089552238806,
#     'avg_size': 17.23507462686567,
#     'avg_rel_length': 2.744533448798441},
#    'UD_Old_East_Slavic-RNC': {'num_trees': 568,
#     'avg_depth': 4.507042253521127,
#     'avg_size': 34.71478873239437,
#     'avg_rel_length': 4.887818237143726},
#    'UD_Old_East_Slavic-TOROT': {'num_trees': 303,
#     'avg_depth': 4.141914191419142,
#     'avg_size': 19.940594059405942,
#     'avg_rel_length': 3.1502813637868257},
#    'UD_Old_French-SRCMF': {'num_trees': 349,
#     'avg_depth': 4.4756446991404015,
#     'avg_size': 19.744985673352435,
#     'avg_rel_length': 2.6942388622841387},
#    'UD_Old_Turkish-Tonqq': {'num_trees': 18,
#     'avg_depth': 3.0,
#     'avg_size': 12.277777777777779,
#     'avg_rel_length': 2.665158371040724},
#    'UD_Persian-PerDT': {'num_trees': 711,
#     'avg_depth': 5.0829817158931085,
#     'avg_size': 23.164556962025316,
#     'avg_rel_length': 3.543108682452945},
#    'UD_Persian-Seraji': {'num_trees': 508,
#     'avg_depth': 6.025590551181103,
#     'avg_size': 29.858267716535433,
#     'avg_rel_length': 4.1954773206751055},
#    'UD_Polish-LFG': {'num_trees': 120,
#     'avg_depth': 3.9916666666666667,
#     'avg_size': 15.016666666666667,
#     'avg_rel_length': 2.876803551609323},
#    'UD_Polish-PDB': {'num_trees': 982,
#     'avg_depth': 5.243380855397149,
#     'avg_size': 23.067209775967413,
#     'avg_rel_length': 3.188371887692036},
#    'UD_Polish-PUD': {'num_trees': 1000,
#     'avg_depth': 4.432,
#     'avg_size': 18.389,
#     'avg_rel_length': 2.877644243841427},
#    'UD_Portuguese-Bosque': {'num_trees': 331,
#     'avg_depth': 5.311178247734139,
#     'avg_size': 27.377643504531722,
#     'avg_rel_length': 3.274001324210991},
#    'UD_Portuguese-GSD': {'num_trees': 970,
#     'avg_depth': 5.370103092783505,
#     'avg_size': 29.939175257731957,
#     'avg_rel_length': 3.3683413105609312},
#    'UD_Portuguese-PUD': {'num_trees': 1000,
#     'avg_depth': 4.506,
#     'avg_size': 23.407,
#     'avg_rel_length': 3.111163327209809},
#    'UD_Romanian-ArT': {'num_trees': 50,
#     'avg_depth': 2.88,
#     'avg_size': 11.46,
#     'avg_rel_length': 2.4834205933682374},
#    'UD_Romanian-Nonstandard': {'num_trees': 614,
#     'avg_depth': 4.962540716612378,
#     'avg_size': 27.319218241042346,
#     'avg_rel_length': 3.560450697508048},
#    'UD_Romanian-RRT': {'num_trees': 613,
#     'avg_depth': 5.2039151712887435,
#     'avg_size': 24.562805872756933,
#     'avg_rel_length': 3.1140333399747626},
#    'UD_Romanian-SiMoNERo': {'num_trees': 485,
#     'avg_depth': 5.760824742268041,
#     'avg_size': 29.870103092783506,
#     'avg_rel_length': 3.2534686270449367},
#    'UD_Russian-GSD': {'num_trees': 420,
#     'avg_depth': 4.802380952380952,
#     'avg_size': 23.354761904761904,
#     'avg_rel_length': 3.3679274135997552},
#    'UD_Russian-PUD': {'num_trees': 1000,
#     'avg_depth': 4.469,
#     'avg_size': 19.355,
#     'avg_rel_length': 2.9576336863859467},
#    'UD_Russian-SynTagRus': {'num_trees': 3480,
#     'avg_depth': 5.412931034482758,
#     'avg_size': 25.425,
#     'avg_rel_length': 3.3776150272946124},
#    'UD_Russian-Taiga': {'num_trees': 261,
#     'avg_depth': 4.689655172413793,
#     'avg_size': 21.754789272030653,
#     'avg_rel_length': 3.3661500528355055},
#    'UD_Sanskrit-UFAL': {'num_trees': 230,
#     'avg_depth': 2.4391304347826086,
#     'avg_size': 8.013043478260869,
#     'avg_rel_length': 2.2881172002170374},
#    'UD_Sanskrit-Vedic': {'num_trees': 188,
#     'avg_depth': 4.111702127659575,
#     'avg_size': 14.441489361702128,
#     'avg_rel_length': 2.5425414364640884},
#    'UD_Scottish_Gaelic-ARCOSG': {'num_trees': 333,
#     'avg_depth': 5.381381381381382,
#     'avg_size': 27.47147147147147,
#     'avg_rel_length': 3.2286838653257544},
#    'UD_Serbian-SET': {'num_trees': 442,
#     'avg_depth': 5.040723981900452,
#     'avg_size': 24.235294117647058,
#     'avg_rel_length': 3.25336071695295},
#    'UD_Skolt_Sami-Giellagas': {'num_trees': 178,
#     'avg_depth': 2.5786516853932584,
#     'avg_size': 12.224719101123595,
#     'avg_rel_length': 3.0064338235294117},
#    'UD_Slovak-SNK': {'num_trees': 471,
#     'avg_depth': 4.53927813163482,
#     'avg_size': 18.182590233545646,
#     'avg_rel_length': 2.882998598785614},
#    'UD_Slovenian-SSJ': {'num_trees': 485,
#     'avg_depth': 4.944329896907217,
#     'avg_size': 23.131958762886597,
#     'avg_rel_length': 3.34593100989393},
#    'UD_Slovenian-SST': {'num_trees': 329,
#     'avg_depth': 3.9908814589665655,
#     'avg_size': 19.890577507598785,
#     'avg_rel_length': 3.0001528117359415},
#    'UD_Soi-AHA': {'num_trees': 8,
#     'avg_depth': 2.25,
#     'avg_size': 6.875,
#     'avg_rel_length': 1.690909090909091},
#    'UD_South_Levantine_Arabic-MADAR': {'num_trees': 100,
#     'avg_depth': 2.57,
#     'avg_size': 7.89,
#     'avg_rel_length': 1.984790874524715},
#    'UD_Spanish-AnCora': {'num_trees': 1432,
#     'avg_depth': 5.841480446927374,
#     'avg_size': 35.49231843575419,
#     'avg_rel_length': 3.630693556320708},
#    'UD_Spanish-GSD': {'num_trees': 332,
#     'avg_depth': 5.731927710843373,
#     'avg_size': 33.01204819277108,
#     'avg_rel_length': 3.5137773722627736},
#    'UD_Spanish-PUD': {'num_trees': 1000,
#     'avg_depth': 4.548,
#     'avg_size': 23.287,
#     'avg_rel_length': 3.1039206424185166},
#    'UD_Swedish-LinES': {'num_trees': 600,
#     'avg_depth': 4.466666666666667,
#     'avg_size': 22.261666666666667,
#     'avg_rel_length': 3.2672007187242644},
#    'UD_Swedish-PUD': {'num_trees': 1000,
#     'avg_depth': 4.12,
#     'avg_size': 19.076,
#     'avg_rel_length': 3.043510169846928},
#    'UD_Swedish-Talbanken': {'num_trees': 739,
#     'avg_depth': 4.493910690121786,
#     'avg_size': 22.100135317997292,
#     'avg_rel_length': 3.3249448934606907},
#    'UD_Swedish_Sign_Language-SSLC': {'num_trees': 18,
#     'avg_depth': 3.111111111111111,
#     'avg_size': 11.055555555555555,
#     'avg_rel_length': 2.422110552763819},
#    'UD_Swiss_German-UZH': {'num_trees': 100,
#     'avg_depth': 3.15,
#     'avg_size': 14.44,
#     'avg_rel_length': 3.020083102493075},
#    'UD_Tagalog-TRG': {'num_trees': 128,
#     'avg_depth': 1.9453125,
#     'avg_size': 5.734375,
#     'avg_rel_length': 2.119891008174387},
#    'UD_Tagalog-Ugnayan': {'num_trees': 94,
#     'avg_depth': 3.3617021276595747,
#     'avg_size': 11.670212765957446,
#     'avg_rel_length': 2.631722880583409},
#    'UD_Tamil-MWTT': {'num_trees': 534,
#     'avg_depth': 1.4831460674157304,
#     'avg_size': 4.8389513108614235,
#     'avg_rel_length': 1.2182662538699691},
#    'UD_Tamil-TTB': {'num_trees': 100,
#     'avg_depth': 4.84,
#     'avg_size': 18.16,
#     'avg_rel_length': 2.6255506607929515},
#    'UD_Telugu-MTG': {'num_trees': 5,
#     'avg_depth': 3.6,
#     'avg_size': 10.4,
#     'avg_rel_length': 1.9423076923076923},
#    'UD_Thai-PUD': {'num_trees': 1000,
#     'avg_depth': 5.098,
#     'avg_size': 22.322,
#     'avg_rel_length': 2.3677089866499417},
#    'UD_Tupinamba-TuDeT': {'num_trees': 210,
#     'avg_depth': 2.3380952380952382,
#     'avg_size': 7.214285714285714,
#     'avg_rel_length': 1.9762376237623762},
#    'UD_Turkish-BOUN': {'num_trees': 383,
#     'avg_depth': 4.971279373368146,
#     'avg_size': 20.532637075718014,
#     'avg_rel_length': 3.078713123092574},
#    'UD_Turkish-FrameNet': {'num_trees': 18,
#     'avg_depth': 3.611111111111111,
#     'avg_size': 12.333333333333334,
#     'avg_rel_length': 1.9504504504504505},
#    'UD_Turkish-GB': {'num_trees': 2880,
#     'avg_depth': 2.084722222222222,
#     'avg_size': 5.964236111111111,
#     'avg_rel_length': 1.4797694591605053},
#    'UD_Turkish-IMST': {'num_trees': 318,
#     'avg_depth': 4.852201257861635,
#     'avg_size': 18.42452830188679,
#     'avg_rel_length': 2.772828127666837},
#    'UD_Turkish-Kenet': {'num_trees': 416,
#     'avg_depth': 4.293269230769231,
#     'avg_size': 15.754807692307692,
#     'avg_rel_length': 2.5538602380225814},
#    'UD_Turkish-Penn': {'num_trees': 75,
#     'avg_depth': 4.386666666666667,
#     'avg_size': 13.586666666666666,
#     'avg_rel_length': 2.4003925417075562},
#    'UD_Turkish-PUD': {'num_trees': 1000,
#     'avg_depth': 4.319,
#     'avg_size': 16.882,
#     'avg_rel_length': 2.7466532401374244},
#    'UD_Turkish-Tourism': {'num_trees': 28,
#     'avg_depth': 4.107142857142857,
#     'avg_size': 13.285714285714286,
#     'avg_rel_length': 2.1344086021505375},
#    'UD_Turkish_German-SAGT': {'num_trees': 605,
#     'avg_depth': 3.568595041322314,
#     'avg_size': 20.608264462809917,
#     'avg_rel_length': 3.648299647096567},
#    'UD_Ukrainian-IU': {'num_trees': 537,
#     'avg_depth': 5.400372439478585,
#     'avg_size': 27.238361266294227,
#     'avg_rel_length': 3.549941888288781},
#    'UD_Upper_Sorbian-UFAL': {'num_trees': 612,
#     'avg_depth': 3.8970588235294117,
#     'avg_size': 17.41830065359477,
#     'avg_rel_length': 3.3661350844277673},
#    'UD_Urdu-UDTB': {'num_trees': 477,
#     'avg_depth': 4.90566037735849,
#     'avg_size': 29.69811320754717,
#     'avg_rel_length': 3.4318085556967386},
#    'UD_Uyghur-UDT': {'num_trees': 399,
#     'avg_depth': 4.192982456140351,
#     'avg_size': 16.37844611528822,
#     'avg_rel_length': 2.7801071155317523},
#    'UD_Vietnamese-VTB': {'num_trees': 572,
#     'avg_depth': 4.236013986013986,
#     'avg_size': 17.65034965034965,
#     'avg_rel_length': 2.8450871632329635},
#    'UD_Warlpiri-UFAL': {'num_trees': 55,
#     'avg_depth': 1.4181818181818182,
#     'avg_size': 5.7272727272727275,
#     'avg_rel_length': 1.6444444444444444},
#    'UD_Welsh-CCG': {'num_trees': 760,
#     'avg_depth': 5.265789473684211,
#     'avg_size': 20.50921052631579,
#     'avg_rel_length': 2.6767819336626677},
#    'UD_Western_Armenian-ArmTDP': {'num_trees': 376,
#     'avg_depth': 4.648936170212766,
#     'avg_size': 25.01595744680851,
#     'avg_rel_length': 3.608335105251967},
#    'UD_Wolof-WTB': {'num_trees': 392,
#     'avg_depth': 5.24234693877551,
#     'avg_size': 25.01530612244898,
#     'avg_rel_length': 3.2161941668366305},
#    'UD_Yoruba-YTB': {'num_trees': 318,
#     'avg_depth': 5.339622641509434,
#     'avg_size': 25.92138364779874,
#     'avg_rel_length': 3.1641392696833677},
#    'UD_Yupik-SLI': {'num_trees': 309,
#     'avg_depth': 2.320388349514563,
#     'avg_size': 8.310679611650485,
#     'avg_rel_length': 1.8975856697819315}}}}
